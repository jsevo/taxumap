# %%
import pandas as pd
from taxumap.input_validation import fill_tax_table

# %% [markdown]
# # Outline

# %% [markdown]
# This notebook briefly describes the proper way of formatting the **taxonomy table** for use in TaxUMAP.
#
# To properly use TaxUMAP, every taxonomical level of an ASV/OTU must be defined. For example:
#
# | OTU       | Kingdom   | Phylum     | Class         | Order           | Family          | Genus       | Species             |
# |:----------|:----------|:-----------|:--------------|:----------------|:----------------|:------------|:--------------------|
# | Uniq53046 | Bacteria  | Firmicutes | Negativicutes | Selenomonadales | Veillonellaceae | Veillonella | Veillonella_atypica |
#
# is a valid entry for the OTU 'Uniq53046', since all taxonomies are resolved. If there is any information missing, for example:
#
#
# | OTU        | Kingdom   | Phylum     |   Class |   Order |   Family |   Genus |   Species |
# |:-----------|:----------|:-----------|--------:|--------:|---------:|--------:|----------:|
# | Uniq114339 | Bacteria  | Firmicutes |         |         |          |         |           |
#
# then we ***must fill the taxonomic levels class through species with a placeholder***. **They cannot be left empty.**
#
# To do this, first fill the data with "np.nan":
#
# | OTU        | Kingdom   | Phylum     |   Class |   Order |   Family |   Genus |   Species |
# |:-----------|:----------|:-----------|--------:|--------:|---------:|--------:|----------:|
# | Uniq114339 | Bacteria  | Firmicutes |     nan |     nan |      nan |     nan |       nan |
#
# and then use the `fill_tax_table()` function, which can be imported using:
# ```python
# from taxumap.input_validation import fill_tax_table
# ```
#
# Using the `fill_tax_table` function on the above row will yield:
#
# | OTU        | Kingdom   | Phylum     | Class                                      | Order                                      | Family                                      | Genus                                      | Species                                      |
# |:-----------|:----------|:-----------|:-------------------------------------------|:-------------------------------------------|:--------------------------------------------|:-------------------------------------------|:---------------------------------------------|
# | Uniq114339 | Bacteria  | Firmicutes | unk_Class_of_Phylum_Firmicutes__Uniq114339 | unk_Order_of_Phylum_Firmicutes__Uniq114339 | unk_Family_of_Phylum_Firmicutes__Uniq114339 | unk_Genus_of_Phylum_Firmicutes__Uniq114339 | unk_Species_of_Phylum_Firmicutes__Uniq114339 |
#
# "unk" stands for "unknown". These labels are **unique** to that OTU, and are important for the proper aggregation of taxonomic information in the TaxUMAP algorithm.
#
# I will demonstrate its use below:

# %%
# Load in your uncleaned data
uncleaned_tax_table = pd.read_csv('example_data/uncleaned_olin_dataset.csv').set_index('OTU')
uncleaned_tax_table
# Out:
#              Kingdom          Phylum                Class              Order  \
# OTU
# Uniq114339  Bacteria      Firmicutes                  NaN                NaN
# Uniq53046   Bacteria      Firmicutes        Negativicutes    Selenomonadales
# Uniq5707    Bacteria      Firmicutes           Clostridia      Clostridiales
# Uniq45364   Bacteria  Proteobacteria  Gammaproteobacteria  Enterobacteriales
# Uniq80019   Bacteria  Proteobacteria  Gammaproteobacteria  Enterobacteriales
# ...              ...             ...                  ...                ...
# Uniq103183  Bacteria      Firmicutes              Bacilli                NaN
# Uniq371     Bacteria   Bacteroidetes          Bacteroidia      Bacteroidales
# Uniq75647   Bacteria  Proteobacteria                  NaN                NaN
# Uniq12824   Bacteria      Firmicutes              Bacilli         Bacillales
# Uniq82221   Bacteria  Proteobacteria   Betaproteobacteria    Burkholderiales
#
#                         Family                         Genus  \
# OTU
# Uniq114339                 NaN                           NaN
# Uniq53046      Veillonellaceae                   Veillonella
# Uniq5707       Lachnospiraceae  Lachnospiraceae_FCS020_group
# Uniq45364   Enterobacteriaceae          Escherichia-Shigella
# Uniq80019   Enterobacteriaceae          Escherichia-Shigella
# ...                        ...                           ...
# Uniq103183                 NaN                           NaN
# Uniq371     Porphyromonadaceae               Parabacteroides
# Uniq75647                  NaN                           NaN
# Uniq12824            Family_XI                       Gemella
# Uniq82221       Alcaligenaceae                 Achromobacter
#
#                                Species
# OTU
# Uniq114339                         NaN
# Uniq53046          Veillonella_atypica
# Uniq5707                           NaN
# Uniq45364                 Enterobacter
# Uniq80019             Escherichia_coli
# ...                                ...
# Uniq103183                         NaN
# Uniq371     Parabacteroides_distasonis
# Uniq75647                          NaN
# Uniq12824          Gemella_haemolysans
# Uniq82221   Achromobacter_aegrifaciens
#
# [2362 rows x 7 columns]

# %% [markdown]
# You can see in the above table that there are many "np.nan" values that we must fill. Now, we use the `fill_tax_table` function:

# %%
cleaned_tax_table = fill_tax_table(uncleaned_tax_table)
cleaned_tax_table
# Out:
#              Kingdom          Phylum  \
# OTU
# Uniq114339  Bacteria      Firmicutes
# Uniq53046   Bacteria      Firmicutes
# Uniq5707    Bacteria      Firmicutes
# Uniq45364   Bacteria  Proteobacteria
# Uniq80019   Bacteria  Proteobacteria
# ...              ...             ...
# Uniq103183  Bacteria      Firmicutes
# Uniq371     Bacteria   Bacteroidetes
# Uniq75647   Bacteria  Proteobacteria
# Uniq12824   Bacteria      Firmicutes
# Uniq82221   Bacteria  Proteobacteria
#
#                                                     Class  \
# OTU
# Uniq114339     unk_Class_of_Phylum_Firmicutes__Uniq114339
# Uniq53046                                   Negativicutes
# Uniq5707                                       Clostridia
# Uniq45364                             Gammaproteobacteria
# Uniq80019                             Gammaproteobacteria
# ...                                                   ...
# Uniq103183                                        Bacilli
# Uniq371                                       Bacteroidia
# Uniq75647   unk_Class_of_Phylum_Proteobacteria__Uniq75647
# Uniq12824                                         Bacilli
# Uniq82221                              Betaproteobacteria
#
#                                                     Order  \
# OTU
# Uniq114339     unk_Order_of_Phylum_Firmicutes__Uniq114339
# Uniq53046                                 Selenomonadales
# Uniq5707                                    Clostridiales
# Uniq45364                               Enterobacteriales
# Uniq80019                               Enterobacteriales
# ...                                                   ...
# Uniq103183         unk_Order_of_Class_Bacilli__Uniq103183
# Uniq371                                     Bacteroidales
# Uniq75647   unk_Order_of_Phylum_Proteobacteria__Uniq75647
# Uniq12824                                      Bacillales
# Uniq82221                                 Burkholderiales
#
#                                                     Family  \
# OTU
# Uniq114339     unk_Family_of_Phylum_Firmicutes__Uniq114339
# Uniq53046                                  Veillonellaceae
# Uniq5707                                   Lachnospiraceae
# Uniq45364                               Enterobacteriaceae
# Uniq80019                               Enterobacteriaceae
# ...                                                    ...
# Uniq103183         unk_Family_of_Class_Bacilli__Uniq103183
# Uniq371                                 Porphyromonadaceae
# Uniq75647   unk_Family_of_Phylum_Proteobacteria__Uniq75647
# Uniq12824                                        Family_XI
# Uniq82221                                   Alcaligenaceae
#
#                                                     Genus  \
# OTU
# Uniq114339     unk_Genus_of_Phylum_Firmicutes__Uniq114339
# Uniq53046                                     Veillonella
# Uniq5707                     Lachnospiraceae_FCS020_group
# Uniq45364                            Escherichia-Shigella
# Uniq80019                            Escherichia-Shigella
# ...                                                   ...
# Uniq103183         unk_Genus_of_Class_Bacilli__Uniq103183
# Uniq371                                   Parabacteroides
# Uniq75647   unk_Genus_of_Phylum_Proteobacteria__Uniq75647
# Uniq12824                                         Gemella
# Uniq82221                                   Achromobacter
#
#                                                       Species
# OTU
# Uniq114339       unk_Species_of_Phylum_Firmicutes__Uniq114339
# Uniq53046                                 Veillonella_atypica
# Uniq5707    unk_Species_of_Genus_Lachnospiraceae_FCS020_gr...
# Uniq45364                                        Enterobacter
# Uniq80019                                    Escherichia_coli
# ...                                                       ...
# Uniq103183           unk_Species_of_Class_Bacilli__Uniq103183
# Uniq371                            Parabacteroides_distasonis
# Uniq75647     unk_Species_of_Phylum_Proteobacteria__Uniq75647
# Uniq12824                                 Gemella_haemolysans
# Uniq82221                          Achromobacter_aegrifaciens
#
# [2362 rows x 7 columns]

# %% [markdown]
# The above taxonomy table is a properly-formatted taxonomy table to be used with TaxUMAP.
#
# 1. Each taxonomic level is resolved.
# 2. The index is the OTU/ASV label.
# 3. Columns are listed in increasing specificity, e.g., Kingdom -> Species.

# %%
cleaned_tax_table.to_csv('example_data/taxonomy.csv')

# %% [markdown]
# # References

# %% [markdown]
# The Olin et al. dataset is used here to provide an practical example of using TaxUMAP. The original publication and dataset can be found below:
#
# ## Publication
#
# > Olin A, Henckel E, Chen Y, et al. Stereotypic Immune System Development in Newborn Children. Cell. 2018;174(5):1277-1292.e14. doi:10.1016/j.cell.2018.06.045
#
# ## Dataset
#
# > Olin, Axel (2018), “Stereotypic Immune System Development in Newborn Children”, Mendeley Data, v1
